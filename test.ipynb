# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://_______:____________@pak.ymtzidm.mongodb.net/?retryWrites=true&w=majority"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['sample_mfilx'] # db 컨택 / 없는것도 바로 생성 가능

# %%
collection  = db['movies'] # 세부 db 컨택 / 없는것도 바로 생성 가능

# %%
client.list_database_names() # db이름 확인
# Out:
# ['sample_mflix', 'admin', 'local']

# %%
# 데이터를 넣을때는 key : value 
# dict형태로 넣어야됨

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/pjk98/Downloads/TFTLCD.csv", encoding='cp949')

# %%
df_dict = df.to_dict(orient= 'records')

# %%
collection.insert_many(df_dict)

# %%
pd.DataFrame(list(collection.find())).drop('_id', axis=1)
# Out:
#          TOOL_NAME         LOTID         GLSID    RECIPEID MODEL_NAME  \
# 0            Tool3  P8GA17009H00  P8GA17008J18  RUN_1ST_23         GA
# 1            Tool2  P8CB1500QP00  P8CB1500N214  RUN_1ST_23         CB
# 2            Tool1  P8CB1500QQ00  P8CB1500N107  RUN_1ST_23         CB
# 3            Tool1  P8CB1500QQ00  P8CB1500N114  RUN_1ST_23         CB
# 4            Tool1  P8CB1500QS00  P8CB1500N312  RUN_1ST_23         CB
# ...            ...           ...           ...         ...        ...
# 3993  P8TCVD060306  P8CB1700V700  P8CB1700TT19  RUN_1ST_23         CB
# 3994  P8TCVD060308  P8GA1600P100  P8GA1600MC16  RUN_1ST_23         GA
# 3995  P8TCVD060308  P8CB1602E100  P8CB1602C305  RUN_1ST_23         CB
# 3996  P8TCVD060309  P8CB17003C00  P8CB17001N17  RUN_1ST_23         CB
# 3997  P8TCVD060308  P8GA1600P700  P8GA1600M408  RUN_1ST_23         GA
#
#             TIME_STAMP PAS연동여부  MP_ALLSTEP.INNER_TEMP.Mean  \
# 0     2011-07-09 13:03      NG                    339.4905
# ...
